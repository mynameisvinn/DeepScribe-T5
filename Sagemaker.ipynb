# %%
import os
import numpy as np
import pandas as pd
import sagemaker
from sagemaker.pytorch import PyTorch

# %%
sagemaker_session = sagemaker.Session()
role = "SageMakerRole"

# %%
bucket = sagemaker_session.default_bucket()
prefix = "sagemaker/deepscribe"
training = sagemaker_session.upload_data('data', key_prefix=prefix)
training
# Out:
# 's3://sagemaker-us-east-1-196099849067/sagemaker/deepscribe'

# %%
estimator = PyTorch(
    entry_point="train.py",
    source_dir="scripts",
    role=role,
    framework_version="1.3.1",
    py_version="py3",
    instance_count=1,
    instance_type='ml.c4.xlarge',
)

# %%
inputs = {'training': training}
estimator.fit(inputs)
# Out:
# 2021-03-09 14:38:50 Starting - Starting the training job...
# 2021-03-09 14:39:14 Starting - Launching requested ML instancesProfilerReport-1615300729: InProgress
# ......
# 2021-03-09 14:40:15 Starting - Preparing the instances for training......
# 2021-03-09 14:41:16 Downloading - Downloading input data......
# 2021-03-09 14:42:23 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-03-09 14:42:25,069 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2021-03-09 14:42:25,072 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-09 14:42:25,086 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-03-09 14:42:28,106 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-03-09 14:42:29,531 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2021-03-09 14:42:29,532 sagemaker-containers INFO     Generating setup.cfg
# 2021-03-09 14:42:29,532 sagemaker-containers INFO     Generating MANIFEST.in
# 2021-03-09 14:42:29,532 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python -m pip install . -r requirements.txt
# Processing /tmp/tmpnys_3o3x/module_dir
# Collecting transformers==4.3.3
#   Downloading transformers-4.3.3-py3-none-any.whl (1.9 MB)
# Collecting nltk==3.5
#   Downloading nltk-3.5.zip (1.4 MB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.6/site-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (2.22.0)
# Collecting regex!=2019.12.17
#   Downloading regex-2020.11.13-cp36-cp36m-manylinux2014_x86_64.whl (723 kB)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /opt/conda/lib/python3.6/site-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (0.7)
# Collecting numpy>=1.17
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting filelock
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.1-cp36-cp36m-manylinux2010_x86_64.whl (3.2 MB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.6/site-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (20.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.43.tar.gz (883 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.6/site-packages (from transformers==4.3.3->-r requirements.txt (line 1)) (4.36.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.6/site-packages (from nltk==3.5->-r requirements.txt (line 2)) (7.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.6/site-packages (from nltk==3.5->-r requirements.txt (line 2)) (0.14.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->transformers==4.3.3->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.3.3->-r requirements.txt (line 1)) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.3.3->-r requirements.txt (line 1)) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.3.3->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.3.3->-r requirements.txt (line 1)) (1.25.7)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging->transformers==4.3.3->-r requirements.txt (line 1)) (2.4.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from packaging->transformers==4.3.3->-r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.6/site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->transformers==4.3.3->-r requirements.txt (line 1)) (8.1.0)
# Building wheels for collected packages: nltk, default-user-module-name, sacremoses
#   Building wheel for nltk (setup.py): started
#   Building wheel for nltk (setup.py): finished with status 'done'
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434674 sha256=4de15c068a2527e63deb53f1ceeaff60970d5a050e6af14825dae217aa6589c9
#   Stored in directory: /root/.cache/pip/wheels/de/5e/42/64abaeca668161c3e2cecc24f864a8fc421e3d07a104fc8a51
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=8963 sha256=42e51fb06e70cf7581e97bf996c76f4e696a7787ce032e5d11e0fb6de442211c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ozm1rcil/wheels/c0/e6/ea/f602c4861167b5125cea526a75417f98495b5127f8ac8877b9
#   Building wheel for sacremoses (setup.py): started
#   Building wheel for sacremoses (setup.py): finished with status 'done'
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-py3-none-any.whl size=893258 sha256=68183cd31e87bdba3e294b200fb4d5b4facbbd18e1adeb7ee3f4c2d7281e7eb2
#   Stored in directory: /root/.cache/pip/wheels/49/25/98/cdea9c79b2d9a22ccc59540b1784b67f06b633378e97f58da2
# Successfully built nltk default-user-module-name sacremoses
# ERROR: sagemaker-pytorch-container 1.3.1 has requirement numpy==1.16.4, but you'll have numpy 1.19.5 which is incompatible.
# Installing collected packages: regex, numpy, filelock, tokenizers, sacremoses, transformers, nltk, default-user-module-name
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.16.4
#     Uninstalling numpy-1.16.4:
#       Successfully uninstalled numpy-1.16.4
# Successfully installed default-user-module-name-1.0.0 filelock-3.0.12 nltk-3.5 numpy-1.19.5 regex-2020.11.13 sacremoses-0.0.43 tokenizers-0.10.1 transformers-4.3.3
# WARNING: You are using pip version 20.0.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.
# 2021-03-09 14:42:41,359 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-09 14:42:41,373 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-09 14:42:41,387 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-03-09 14:42:41,402 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2021-03-09-14-38-48-284",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-196099849067/pytorch-training-2021-03-09-14-38-48-284/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-196099849067/pytorch-training-2021-03-09-14-38-48-284/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2021-03-09-14-38-48-284","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-196099849067/pytorch-training-2021-03-09-14-38-48-284/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python train.py
# 2021-03-09 14:42:59 Uploading - Uploading generated training model
# 2021-03-09 14:42:59 Failed - Training job failed
# ProfilerReport-1615300729: Stopping
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Traceback (most recent call last):
#   File "train.py", line 74, in <module>
#     m, t, o = create_model()
#   File "/opt/ml/code/t1000/model.py", line 5, in create_model
#     tokenizer = T5Tokenizer.from_pretrained('t5-base')
#   File "/opt/conda/lib/python3.6/site-packages/transformers/utils/dummy_sentencepiece_objects.py", line 92, in from_pretrained
#     requires_sentencepiece(self)
#   File "/opt/conda/lib/python3.6/site-packages/transformers/file_utils.py", line 491, in requires_sentencepiece
#     raise ImportError(SENTENCEPIECE_IMPORT_ERROR.format(name))
# ImportError:
# T5Tokenizer requires the SentencePiece library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment.
#
# 2021-03-09 14:42:46,492 sagemaker-containers ERROR    ExecuteUserScriptError:
# Command "/opt/conda/bin/python train.py"
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Traceback (most recent call last):
#   File "train.py", line 74, in <module>
#     m, t, o = create_model()
#   File "/opt/ml/code/t1000/model.py", line 5, in create_model
#     tokenizer = T5Tokenizer.from_pretrained('t5-base')
#   File "/opt/conda/lib/python3.6/site-packages/transformers/utils/dummy_sentencepiece_objects.py", line 92, in from_pretrained
#     requires_sentencepiece(self)
#   File "/opt/conda/lib/python3.6/site-packages/transformers/file_utils.py", line 491, in requires_sentencepiece
#     raise ImportError(SENTENCEPIECE_IMPORT_ERROR.format(name))
# ImportError:
# T5Tokenizer requires the SentencePiece library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment.
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-11-63d7d02518f9> in <module>
#       1 inputs = {'training': training}
# ----> 2 estimator.fit(inputs)
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     662         self.jobs.append(self.latest_training_job)
#     663         if wait:
# --> 664             self.latest_training_job.wait(logs=logs)
#     665
#     666     def _compilation_job_name(self):
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1589         # If logs are requested, call logs_for_jobs.
#    1590         if logs != "None":
# -> 1591             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1592         else:
#    1593             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3638
#    3639         if wait:
# -> 3640             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3641             if dot:
#    3642                 print()
#
# ~/anaconda3/lib/python3.8/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3215             reason = desc.get("FailureReason", "(No reason provided)")
#    3216             job_type = status_key_name.replace("JobStatus", " job")
# -> 3217             raise exceptions.UnexpectedStatusException(
#    3218                 message="Error for {job_type} {job_name}: {status}. Reason: {reason}".format(
#    3219                     job_type=job_type, job_name=job, status=status, reason=reason
#
# UnexpectedStatusException: Error for Training job pytorch-training-2021-03-09-14-38-48-284: Failed. Reason: AlgorithmError: ExecuteUserScriptError:
# Command "/opt/conda/bin/python train.py"
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Traceback (most recent call last):
#   File "train.py", line 74, in <module>
#     m, t, o = create_model()
#   File "/opt/ml/code/t1000/model.py", line 5, in create_model
#     tokenizer = T5Tokenizer.from_pretrained('t5-base')
#   File "/opt/conda/lib/python3.6/site-packages/transformers/utils/dummy_sentencepiece_objects.py", line 92, in from_pretrained
#     requires_sentencepiece(self)
#   File "/opt/conda/lib/python3.6/site-packages/transformers/file_utils.py", line 491, in requires_sentencepiece
#     raise ImportError(SENTENCEPIECE_IMPORT_ERROR.format(name))
# ImportError:
# T5Tokenizer requires the SentencePiece library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment.
